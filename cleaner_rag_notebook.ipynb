# %%
from rag_helper import RAGBase
from ingest import load_faq_data, build_index

# %%
from dotenv import load_dotenv
load_dotenv()  # Load environment variables from .env file

from anthropic import Anthropic
client = Anthropic()

# %%
documents = load_faq_data()
index = build_index(documents)

assistant = RAGBase(index=index, llm_client=client)

# %%
assistant.rag("I just discovered the course, how can I join?")
# Out:
# '# Welcome to the Course!\n\nYes, you can definitely join! Here\'s what you need to know:\n\n## Getting Started\n\n1. **You don\'t need to wait for confirmation** – You\'re accepted and can start learning right away\n2. **No registration needed to begin** – You can start watching videos and submitting homework without formally registering\n\n## How to Join and Get Started\n\nFollow this workflow:\n\n1. **Review the course materials:**\n   - [LLM Zoomcamp docs](https://datatalks.club/docs/courses/llm-zoomcamp/)\n   - [General Zoomcamp logistics docs](https://datatalks.club/docs/courses/zoomcamp-logistics/)\n   - [LLM Zoomcamp GitHub repository](https://github.com/DataTalksClub/llm-zoomcamp)\n\n2. **Check deadlines** on the [course management platform](https://courses.datatalks.club/llm-zoomcamp-2026/)\n\n3. **Follow the typical workflow:**\n   - Watch lesson videos\n   - Work through lesson notebooks/code\n   - Read homework instructions on GitHub\n   - Submit answers through the course platform before deadlines\n\n## Important Note About Certificates\n\nIf you want a **certificate**, you must:\n- Join during a "live" cohort (not self-paced mode)\n- Complete and submit your capstone project on time\n- Participate in peer-reviewing 3 capstone projects\n\nYou can start whenever you want, and videos/materials are available now!'
