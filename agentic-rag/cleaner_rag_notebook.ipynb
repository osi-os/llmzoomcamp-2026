# %%
from rag_helper import RAGBase
from ingest import load_faq_data, build_index

# %%
from dotenv import load_dotenv
load_dotenv()  # Load environment variables from .env file

from anthropic import Anthropic
client = Anthropic()

# %%
documents = load_faq_data()
index = build_index(documents)

assistant = RAGBase(index=index, llm_client=client)

# %%
assistant.rag("I just discovered the course, how can I join?")
# Out:
# # Welcome to the Course!
#
# Great question! Here's how you can get started:
#
# ## Joining the Course
#
# **Yes, you can join!** You don't even need to wait for a confirmation email. Here's what you need to know:
#
# - **No formal registration needed** – You can start learning and submitting homework right away without registering
# - **Registration is optional** – It's only used to gauge interest before the start date
# - **You're accepted** – Just begin with the course materials whenever you're ready
#
# ## How to Get Started
#
# 1. **Visit the course resources:**
#    - [LLM Zoomcamp docs](https://datatalks.club/docs/courses/llm-zoomcamp/)
#    - [General Zoomcamp logistics docs](https://datatalks.club/docs/courses/zoomcamp-logistics/)
#    - [LLM Zoomcamp GitHub repository](https://github.com/DataTalksClub/llm-zoomcamp)
#
# 2. **Check the deadlines** in the [course management platform](https://courses.datatalks.club/llm-zoomcamp-2026/)
#
# 3. **Follow this workflow:**
#    - Watch the lesson videos
#    - Work through the lesson notebooks/code
#    - Read homework instructions on GitHub
#    - Submit answers through the course platform before deadlines
#
# ## Important Note About Certificates
#
# If you want to earn a certificate, you must complete the course with an active cohort (not self-paced), as certificates require peer-reviewing 3 capstone projects.
#
# Feel free to ask if you have any other questions!
# "# Welcome to the Course!\n\nGreat question! Here's how you can get started:\n\n## Joining the Course\n\n**Yes, you can join!** You don't even need to wait for a confirmation email. Here's what you need to know:\n\n- **No formal registration needed** – You can start learning and submitting homework right away without registering\n- **Registration is optional** – It's only used to gauge interest before the start date\n- **You're accepted** – Just begin with the course materials whenever you're ready\n\n## How to Get Started\n\n1. **Visit the course resources:**\n   - [LLM Zoomcamp docs](https://datatalks.club/docs/courses/llm-zoomcamp/)\n   - [General Zoomcamp logistics docs](https://datatalks.club/docs/courses/zoomcamp-logistics/)\n   - [LLM Zoomcamp GitHub repository](https://github.com/DataTalksClub/llm-zoomcamp)\n\n2. **Check the deadlines** in the [course management platform](https://courses.datatalks.club/llm-zoomcamp-2026/)\n\n3. **Follow this workflow:**\n   - Watch the lesson videos\n   - Work through the lesson notebooks/code\n   - Read homework instructions on GitHub\n   - Submit answers through the course platform before deadlines\n\n## Important Note About Certificates\n\nIf you want to earn a certificate, you must complete the course with an active cohort (not self-paced), as certificates require peer-reviewing 3 capstone projects.\n\nFeel free to ask if you have any other questions!"

# %%
assistant.rag("Can I still join the course after it started?")
# Out:
# # Answer
#
# Yes, you can still join the course after it started!
#
# However, there's an important condition: **if you want to receive a certificate, you need to submit your Capstone project while submissions are still being accepted.**
#
# Here are the key points:
#
# - You can start learning whenever you want - the videos and materials are available
# - You can submit homework at any time (while the submission form is open)
# - To get a certificate, you must complete the Capstone project before the submission deadline closes
# - You'll also need to participate in peer-reviewing 3 Capstone projects from other participants (this is only possible during the live cohort when the course is running)
#
# So in summary: join anytime, but plan to complete your Capstone project before the submission deadline if you want the certificate!
# "# Answer\n\nYes, you can still join the course after it started! \n\nHowever, there's an important condition: **if you want to receive a certificate, you need to submit your Capstone project while submissions are still being accepted.**\n\nHere are the key points:\n\n- You can start learning whenever you want - the videos and materials are available\n- You can submit homework at any time (while the submission form is open)\n- To get a certificate, you must complete the Capstone project before the submission deadline closes\n- You'll also need to participate in peer-reviewing 3 Capstone projects from other participants (this is only possible during the live cohort when the course is running)\n\nSo in summary: join anytime, but plan to complete your Capstone project before the submission deadline if you want the certificate!"
